# %% [markdown]
# Attempts to join the REPD with BM unit data, in order to find the locations of BM units.

# %%
import pandas as pd
from pathlib import Path

# %load_ext nb_black

DATA_PATH = Path("../data")
# Out:
# The nb_black extension is already loaded. To reload it, use:
#   %reload_ext nb_black

# %% [markdown]
# # REPD
# This contains wind farm locations

# %%
repd = pd.read_csv(DATA_PATH / "repd-october-2022.csv", encoding="ISO-8859-1")

# %%
repd
# Out:
#      Old Ref ID  Ref ID Record Last Updated (dd/mm/yyyy)  \
# 0       N00053B       1                       07/07/2009
# 1         AA110       2                       20/11/2017
# 2         B0730       3                       04/06/2020
# 3       1106000       4                       18/12/2003
# 4       2047000       5                       29/09/2005
# ...         ...     ...                              ...
# 8011        NaN   12297                       13/10/2022
# 8012        NaN   12298                       13/10/2022
# 8013        NaN   12299                       13/10/2022
# 8014        NaN   12300                       13/10/2022
# 8015        NaN   12301                       13/10/2022
#
#                           Operator (or Applicant)  \
# 0                                      RWE npower
# 1     Orsted (formerly Dong Energy) / Peel Energy
# 2              Scottish and Southern Energy (SSE)
# 3                          Energy Power Resources
# 4                                         Agrigen
# ...                                           ...
# 8011                        BayWa r.e. UK Limited
# 8012                        BayWa r.e. UK Limited
# 8013                        BayWa r.e. UK Limited
# 8014                                   Low Carbon
# 8015                                   Low Carbon
#
#                                               Site Name      Technology Type  \
# 0                        Aberthaw Power Station Biomass  Biomass (co-firing)
# 1                                 Hunterston - cofiring  Biomass (co-firing)
# 2                         Ferrybridge Multifuel 2 (FM2)     EfW Incineration
# 3                        Thetford Biomass Power Station  Biomass (dedicated)
# 4                         Nunn Mills Road Biomass Plant  Biomass (dedicated)
# ...                                                 ...                  ...
# 8011   Back Lane, Skerne - Solar Farm & Battery Storage              Battery
# 8012                            Scurf Dyke - Solar Farm  Solar Photovoltaics
# 8013                            Scurf Dyke - Solar Farm              Battery
# 8014  Inkersall Road, Staveley - Solar Photovoltaic ...  Solar Photovoltaics
# 8015  Inkersall Road, Staveley - Solar Photovoltaic ...              Battery
#
#             Storage Type Storage Co-location REPD Ref ID  \
# 0                    NaN                             NaN
# 1                    NaN                             NaN
# 2                    NaN                             NaN
# 3                    NaN                             NaN
# 4                    NaN                             NaN
# ...                  ...                             ...
# 8011  Co-located with RE                           12296
# 8012                 NaN                           12299
# 8013  Co-located with RE                           12298
# 8014                 NaN                           12301
# 8015  Co-located with RE                           12300
#
#       Installed Capacity (MWelec) CHP Enabled  ...  Appeal Refused  \
# 0                            35.0          No  ...             NaN
# 1                           170.0          No  ...             NaN
# 2                            70.0          No  ...             NaN
# 3                            38.5          No  ...             NaN
# 4                             8.8          No  ...             NaN
# ...                           ...         ...  ...             ...
# 8011                         30.0          No  ...             NaN
# 8012                         49.9          No  ...             NaN
# 8013                          NaN          No  ...             NaN
# 8014                         31.0          No  ...             NaN
# 8015                          NaN          No  ...             NaN
#
#      Appeal Granted  Planning Permission Granted  \
# 0               NaN                   03/09/2004
# 1               NaN                          NaN
# 2               NaN                   28/10/2015
# 3               NaN                   05/05/1995
# 4               NaN                          NaN
# ...             ...                          ...
# 8011            NaN                   23/10/2020
# 8012            NaN                   18/03/2020
# 8013            NaN                   18/03/2020
# 8014            NaN                   20/04/2021
# 8015            NaN                   20/04/2021
#
#       Secretary of State - Intervened  Secretary of State - Refusal  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
# ...                               ...                           ...
# 8011                              NaN                           NaN
# 8012                              NaN                           NaN
# 8013                              NaN                           NaN
# 8014                              NaN                           NaN
# 8015                              NaN                           NaN
#
#       Secretary of State - Granted Planning Permission Expired  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                  28/10/2020
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 8011                           NaN                  23/10/2023
# 8012                           NaN                  18/03/2023
# 8013                           NaN                  18/03/2023
# 8014                           NaN                         NaN
# 8015                           NaN                         NaN
#
#      Under Construction Operational Heat Network Ref
# 0            01/05/2006  01/05/2007              NaN
# 1                   NaN         NaN              NaN
# 2            01/09/2016  20/12/2019              NaN
# 3                   NaN  02/10/1998              NaN
# 4                   NaN         NaN              NaN
# ...                 ...         ...              ...
# 8011                NaN         NaN              NaN
# 8012                NaN         NaN              NaN
# 8013                NaN         NaN              NaN
# 8014                NaN         NaN              NaN
# 8015                NaN         NaN              NaN
#
# [8016 rows x 50 columns]

# %%
df_repd_wind = repd[repd["Technology Type"].str.contains("Wind")].sort_values(
    by="Installed Capacity (MWelec)", ascending=False
)
df_repd_wind
# Out:
#      Old Ref ID  Ref ID Record Last Updated (dd/mm/yyyy)  \
# 2009      C1830    2473                       08/04/2022
# 2065      A0248    2541                       12/04/2022
# 2008      B0850    2472                       18/03/2022
# 2014      A0250    2484                       15/02/2022
# 5076        NaN    6483                       11/04/2022
# ...         ...     ...                              ...
# 6766        NaN    9676                       22/09/2021
# 6987        NaN   10241                       22/03/2022
# 7025        NaN   10343                       23/12/2021
# 7956        NaN   12186                       28/09/2022
# 8008        NaN   12294                       13/10/2022
#
#                                 Operator (or Applicant)  \
# 2009                      Orsted (formerly Dong Energy)
# 2065  SSE/Equinor (formerly Statoil, formerly Forewind)
# 2008                      Orsted (formerly Dong Energy)
# 2014               Vattenfall/Scottish Power Renewables
# 5076               Vattenfall/Scottish Power Renewables
# ...                                                 ...
# 6766                                 Hill Power Limited
# 6987                          Northern Lighthouse Board
# 7025                   Yorkshire Water Services Limited
# 7956                  Reserve Force & Cadet Association
# 8008                                      EnergieKontor
#
#                                               Site Name Technology Type  \
# 2009                                          Hornsea 4   Wind Offshore
# 2065          Dogger Bank A & B (was Creyke Beck A & B)   Wind Offshore
# 2008                                          Hornsea 3   Wind Offshore
# 2014           The East Anglia Array - Norfolk Vanguard   Wind Offshore
# 5076             The East Anglia Array - Norfolk Boreas   Wind Offshore
# ...                                                 ...             ...
# 6766                      Tullycallidy Road Replacement    Wind Onshore
# 6987  Start Point Lighthouse - Supply and Installati...    Wind Onshore
# 7025       Aygill Intake - Solar Panels & Wind Turbines    Wind Onshore
# 7956  HMS Eaglet, Sefton Street - Wind Turbine & Sol...    Wind Onshore
# 8008  Garcrogo Hill And Barmark Hill, Corsock - Wind...    Wind Onshore
#
#             Storage Type Storage Co-location REPD Ref ID  \
# 2009                 NaN                             NaN
# 2065                 NaN                             NaN
# 2008                 NaN                             NaN
# 2014                 NaN                             NaN
# 5076                 NaN                             NaN
# ...                  ...                             ...
# 6766                 NaN                             NaN
# 6987                 NaN                             NaN
# 7025                 NaN                            9835
# 7956  Co-located with RE                           12185
# 8008                 NaN                           12295
#
#       Installed Capacity (MWelec) CHP Enabled  ...  Appeal Refused  \
# 2009                       2600.0         NaN  ...             NaN
# 2065                       2400.0         NaN  ...             NaN
# 2008                       2400.0          No  ...             NaN
# 2014                       1800.0          No  ...             NaN
# 5076                       1800.0         NaN  ...             NaN
# ...                           ...         ...  ...             ...
# 6766                          NaN          No  ...             NaN
# 6987                          NaN          No  ...             NaN
# 7025                          NaN          No  ...             NaN
# 7956                          NaN          No  ...             NaN
# 8008                          NaN          No  ...             NaN
#
#      Appeal Granted  Planning Permission Granted  \
# 2009            NaN                          NaN
# 2065            NaN                   17/02/2015
# 2008            NaN                   30/12/2020
# 2014            NaN                   11/02/2022
# 5076            NaN                   10/12/2021
# ...             ...                          ...
# 6766            NaN                          NaN
# 6987            NaN                          NaN
# 7025            NaN                   16/12/2021
# 7956            NaN                          NaN
# 8008            NaN                          NaN
#
#       Secretary of State - Intervened  Secretary of State - Refusal  \
# 2009                              NaN                           NaN
# 2065                              NaN                           NaN
# 2008                              NaN                           NaN
# 2014                              NaN                           NaN
# 5076                              NaN                           NaN
# ...                               ...                           ...
# 6766                              NaN                           NaN
# 6987                              NaN                           NaN
# 7025                              NaN                           NaN
# 7956                              NaN                           NaN
# 8008                              NaN                           NaN
#
#       Secretary of State - Granted Planning Permission Expired  \
# 2009                           NaN                         NaN
# 2065                           NaN                         NaN
# 2008                           NaN                  13/12/2027
# 2014                    11/02/2022                  11/02/2027
# 5076                           NaN                  10/12/2026
# ...                            ...                         ...
# 6766                           NaN                         NaN
# 6987                           NaN                         NaN
# 7025                           NaN                  16/12/2024
# 7956                           NaN                         NaN
# 8008                           NaN                         NaN
#
#      Under Construction Operational Heat Network Ref
# 2009                NaN         NaN              NaN
# 2065         01/07/2021         NaN              NaN
# 2008                NaN         NaN              NaN
# 2014                NaN         NaN              NaN
# 5076                NaN         NaN              NaN
# ...                 ...         ...              ...
# 6766                NaN         NaN              NaN
# 6987                NaN         NaN              NaN
# 7025                NaN         NaN              NaN
# 7956                NaN         NaN              NaN
# 8008                NaN         NaN              NaN
#
# [2378 rows x 50 columns]

# %% [markdown]
# # BM data
# Need to merge one sheet which has nice capacity information, and another which has nice party information - between them these should give us enough to map to the REPD

# %%
b1420 = pd.read_csv(DATA_PATH / "B1420.csv", header=1)
b1420.head()
# Out:
#                 Time Series ID    Business Type Registered Resource EIC code  \
# 0  NGET-EMFIP-CONF-TS-00740037  Production unit             48WSTN0000SGRWOC
# 1  NGET-EMFIP-CONF-TS-00740037  Production unit             48W00000SGRWO-2J
# 2  NGET-EMFIP-CONF-TS-00740037  Production unit             48W00000SGRWO-3H
# 3  NGET-EMFIP-CONF-TS-00740037  Production unit             48W00000SGRWO-4F
# 4  NGET-EMFIP-CONF-TS-00740037  Production unit             48W00000SGRWO-5D
#
#   BM Unit ID NGC BM Unit ID Registered Resource Name  \
# 0        NaN          SGRWO                    SGRWO
# 1  T_SGRWO-2        SGRWO-2                  SGRWO-2
# 2  T_SGRWO-3        SGRWO-3                  SGRWO-3
# 3  T_SGRWO-4        SGRWO-4                  SGRWO-4
# 4  T_SGRWO-5        SGRWO-5                  SGRWO-5
#
#                       PSR Type Effective From (Date) Effective To (Date)  \
# 0  &ldquo;Wind Offshore&ldquo;            2022-12-05          2022-12-05
# 1  &ldquo;Wind Offshore&ldquo;            2022-12-06                 NaN
# 2  &ldquo;Wind Offshore&ldquo;            2022-12-06                 NaN
# 3  &ldquo;Wind Offshore&ldquo;            2022-12-06                 NaN
# 4  &ldquo;Wind Offshore&ldquo;            2022-12-06                 NaN
#
#    Voltage Limit (KVT) (Production Unit Level)  \
# 0                                        275.0
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    Installed Capacity (Nominal Power) (MW)
# 0                                    300.0
# 1                                     80.0
# 2                                    150.0
# 3                                    140.0
# 4                                     80.0

# %%
b1420 = b1420.set_index("BM Unit ID")

# %%
reg_units = pd.read_csv(DATA_PATH / "reg_bm_units.csv", header=1)

reg_units = reg_units.set_index("BM Unit ID")

# %%
df_bm = pd.merge(reg_units, b1420, left_index=True, right_index=True, how="left")
df_bm["PSR Type"] = df_bm["PSR Type"].str.strip("&ldquo;")

# %%
df_bm.groupby("PSR Type").count()
# Out:
#                                  BMU Name  Party Name  Party ID  BMU Type  \
# PSR Type
# Biomass                                 2           2         2         2
# Fossil Gas                             54          54        54        54
# Fossil Hard coa                        10          10        10        10
# Fossil Oi                               9           9         9         9
# Generation                             81          81        81        81
# Hydro Run-of-river and poundage        22          22        22        22
# Loa                                    32          32        32        32
# Nuclear                                18          18        18        18
# Other                                   3           3         3         3
# Wind Offshore                          30          30        30        30
# Wind Onshore                           51          51        51        51
#
#                                  NGC BMU Name  GSP Group Id  GSP Group Name  \
# PSR Type
# Biomass                                     2             0               0
# Fossil Gas                                 53             7               7
# Fossil Hard coa                            10             0               0
# Fossil Oi                                   9             6               6
# Generation                                 81            16              16
# Hydro Run-of-river and poundage            22             0               0
# Loa                                        32             3               3
# Nuclear                                    18             0               0
# Other                                       3             1               1
# Wind Offshore                              30             1               1
# Wind Onshore                               51            16              16
#
#                                  Trading Unit Name  Prod/Cons Flag  \
# PSR Type
# Biomass                                          1               0
# Fossil Gas                                      30               2
# Fossil Hard coa                                 10               0
# Fossil Oi                                        8               4
# Generation                                      32              21
# Hydro Run-of-river and poundage                 16               0
# Loa                                             13               1
# Nuclear                                         18               0
# Other                                            3               1
# Wind Offshore                                    5               1
# Wind Onshore                                    16              22
#
#                                  Prod/Cons Status  ...  \
# PSR Type                                           ...
# Biomass                                         2  ...
# Fossil Gas                                     54  ...
# Fossil Hard coa                                10  ...
# Fossil Oi                                       9  ...
# Generation                                     81  ...
# Hydro Run-of-river and poundage                22  ...
# Loa                                            32  ...
# Nuclear                                        18  ...
# Other                                           3  ...
# Wind Offshore                                  30  ...
# Wind Onshore                                   51  ...
#
#                                   Credit Qualifying Status  Time Series ID  \
# PSR Type
# Biomass                                                  2               2
# Fossil Gas                                              54              54
# Fossil Hard coa                                         10              10
# Fossil Oi                                                9               9
# Generation                                              81              81
# Hydro Run-of-river and poundage                         22              22
# Loa                                                     32              32
# Nuclear                                                 18              18
# Other                                                    3               3
# Wind Offshore                                           30              30
# Wind Onshore                                            51              51
#
#                                  Business Type  Registered Resource EIC code  \
# PSR Type
# Biomass                                      2                             2
# Fossil Gas                                  54                            54
# Fossil Hard coa                             10                            10
# Fossil Oi                                    9                             9
# Generation                                  81                            81
# Hydro Run-of-river and poundage             22                            22
# Loa                                         32                            32
# Nuclear                                     18                            18
# Other                                        3                             3
# Wind Offshore                               30                            30
# Wind Onshore                                51                            51
#
#                                  NGC BM Unit ID  Registered Resource Name  \
# PSR Type
# Biomass                                       2                         2
# Fossil Gas                                   54                        54
# Fossil Hard coa                              10                        10
# Fossil Oi                                     9                         9
# Generation                                   81                        81
# Hydro Run-of-river and poundage              22                        22
# Loa                                          32                        32
# Nuclear                                      18                        18
# Other                                         3                         3
# Wind Offshore                                30                        30
# Wind Onshore                                 51                        51
#
#                                  Effective From (Date)  Effective To (Date)  \
# PSR Type
# Biomass                                              2                    0
# Fossil Gas                                          54                    0
# Fossil Hard coa                                     10                    0
# Fossil Oi                                            9                    0
# Generation                                          81                    0
# Hydro Run-of-river and poundage                     22                    0
# Loa                                                 32                    0
# Nuclear                                             18                    0
# Other                                                3                    0
# Wind Offshore                                       30                    0
# Wind Onshore                                        51                    0
#
#                                  Voltage Limit (KVT) (Production Unit Level)  \
# PSR Type
# Biomass                                                                    0
# Fossil Gas                                                                 0
# Fossil Hard coa                                                            0
# Fossil Oi                                                                  0
# Generation                                                                 0
# Hydro Run-of-river and poundage                                            0
# Loa                                                                        0
# Nuclear                                                                    0
# Other                                                                      0
# Wind Offshore                                                              0
# Wind Onshore                                                               0
#
#                                  Installed Capacity (Nominal Power) (MW)
# PSR Type
# Biomass                                                                2
# Fossil Gas                                                            54
# Fossil Hard coa                                                       10
# Fossil Oi                                                              9
# Generation                                                            81
# Hydro Run-of-river and poundage                                       22
# Loa                                                                   32
# Nuclear                                                               18
# Other                                                                  3
# Wind Offshore                                                         30
# Wind Onshore                                                          51
#
# [11 rows x 36 columns]

# %%
df_bm_wind = df_bm[df_bm["PSR Type"].fillna("unknown").str.contains("Wind")]

# %%
df_bm_wind.columns
df_bm_wind = df_bm_wind.sort_values(
    by="Installed Capacity (Nominal Power) (MW)", ascending=False
)

# %%
df_bm_wind
# Out:
#                           BMU Name                     Party Name  Party ID  \
# BM Unit ID
# T_HOWBO-3            HORNSEA_WF_2C         Soundmark Wind Limited  ORSTED03
# T_HOWAO-1               HORNSEA_1A              Hornsea 1 Limited   DONG013
# T_HOWAO-2               HORNSEA_1B              Hornsea 1 Limited   DONG013
# T_HOWAO-3               HORNSEA_1C              Hornsea 1 Limited   DONG013
# T_WLNYO-3                 WALNEY_3           Walney Extension Ltd   DONG012
# ...                            ...                            ...       ...
# T_COUWW-1           Cour Wind Farm  Cour Wind farm (Scotland) Ltd   CWF2016
# T_ANSUW-1              An Suidhe 1         Statkraft Markets Gmbh  STATKRA1
# E_TULWW-1           Tullo Windfarm             Eneco Energy Trade   ENECOUK
# E_CLFLW-1            Clachan Flats     SP Renewables (UK) Limited   SPCRE01
# E_TLYMW-1   Tullymurdoch Wind Farm        Limejump Energy Limited     ANGEL
#
#            BMU Type NGC BMU Name GSP Group Id         GSP Group Name  \
# BM Unit ID
# T_HOWBO-3         T      HOWBO-3          NaN                    NaN
# T_HOWAO-1         T      HOWAO-1          NaN                    NaN
# T_HOWAO-2         T      HOWAO-2          NaN                    NaN
# T_HOWAO-3         T      HOWAO-3          NaN                    NaN
# T_WLNYO-3         T      WLNYO-3          NaN                    NaN
# ...             ...          ...          ...                    ...
# T_COUWW-1         T      COUWW-1          NaN                    NaN
# T_ANSUW-1         T      ANSUW-1          NaN                    NaN
# E_TULWW-1         E      TULWW-1           _P  NORTH of SCOTLAND GSP
# E_CLFLW-1         E      CLFLW-1           _P  NORTH of SCOTLAND GSP
# E_TLYMW-1         E      TLYMW-1           _P  NORTH of SCOTLAND GSP
#
#            Trading Unit Name Prod/Cons Flag Prod/Cons Status  ...  \
# BM Unit ID                                                    ...
# T_HOWBO-3                NaN            NaN                P  ...
# T_HOWAO-1                NaN            NaN                P  ...
# T_HOWAO-2                NaN            NaN                P  ...
# T_HOWAO-3                NaN            NaN                P  ...
# T_WLNYO-3                NaN            NaN                P  ...
# ...                      ...            ...              ...  ...
# T_COUWW-1                NaN            NaN                P  ...
# T_ANSUW-1                NaN              P                P  ...
# E_TULWW-1         DEFAULT__P              P                P  ...
# E_CLFLW-1         DEFAULT__P              P                P  ...
# E_TLYMW-1         DEFAULT__P              C                C  ...
#
#                          Time Series ID    Business Type  \
# BM Unit ID
# T_HOWBO-3   NGET-EMFIP-CONF-TS-00740033  Production unit
# T_HOWAO-1   NGET-EMFIP-CONF-TS-00053328  Production unit
# T_HOWAO-2   NGET-EMFIP-CONF-TS-00053328  Production unit
# T_HOWAO-3   NGET-EMFIP-CONF-TS-00053328  Production unit
# T_WLNYO-3   NGET-EMFIP-CONF-TS-00000001  Production unit
# ...                                 ...              ...
# T_COUWW-1   NGET-EMFIP-CONF-TS-00053346  Production unit
# T_ANSUW-1   NGET-EMFIP-CONF-TS-00002001  Production unit
# E_TULWW-1   NGET-EMFIP-CONF-TS-00053363  Production unit
# E_CLFLW-1   NGET-EMFIP-CONF-TS-00053345  Production unit
# E_TLYMW-1   NGET-EMFIP-CONF-TS-00053361  Production unit
#
#             Registered Resource EIC code  NGC BM Unit ID  \
# BM Unit ID
# T_HOWBO-3               48W00000HOWBO-3D         HOWBO-3
# T_HOWAO-1               48W00000HOWAO-1M         HOWAO-1
# T_HOWAO-2               48W00000HOWAO-2K         HOWAO-2
# T_HOWAO-3               48W00000HOWAO-3I         HOWAO-3
# T_WLNYO-3               48W00000WLNYO-31         WLNYO-3
# ...                                  ...             ...
# T_COUWW-1               48W00000COUWW-16         COUWW-1
# T_ANSUW-1               48W00000ANSUW-1E         ANSUW-1
# E_TULWW-1               48W00000TULWW-1U         TULWW-1
# E_CLFLW-1               48W00000CLFLW-1O         CLFLW-1
# E_TLYMW-1               48W00000TLYMW-1S         TLYMW-1
#
#             Registered Resource Name       PSR Type  Effective From (Date)  \
# BM Unit ID
# T_HOWBO-3                    HOWBO-3  Wind Offshore             2021-10-11
# T_HOWAO-1                    HOWAO-1  Wind Offshore             2019-01-21
# T_HOWAO-2                    HOWAO-2  Wind Offshore             2019-01-21
# T_HOWAO-3                    HOWAO-3  Wind Offshore             2019-01-21
# T_WLNYO-3                    WLNYO-3  Wind Offshore             2017-10-30
# ...                              ...            ...                    ...
# T_COUWW-1                    COUWW-1   Wind Onshore             2019-01-23
# T_ANSUW-1                    ANSUW-1   Wind Onshore             2013-01-01
# E_TULWW-1                    TULWW-1   Wind Onshore             2019-01-23
# E_CLFLW-1                    CLFLW-1   Wind Onshore             2019-01-23
# E_TLYMW-1                    TLYMW-1   Wind Onshore             2019-01-23
#
#             Effective To (Date)  Voltage Limit (KVT) (Production Unit Level)  \
# BM Unit ID
# T_HOWBO-3                   NaN                                          NaN
# T_HOWAO-1                   NaN                                          NaN
# T_HOWAO-2                   NaN                                          NaN
# T_HOWAO-3                   NaN                                          NaN
# T_WLNYO-3                   NaN                                          NaN
# ...                         ...                                          ...
# T_COUWW-1                   NaN                                          NaN
# T_ANSUW-1                   NaN                                          NaN
# E_TULWW-1                   NaN                                          NaN
# E_CLFLW-1                   NaN                                          NaN
# E_TLYMW-1                   NaN                                          NaN
#
#             Installed Capacity (Nominal Power) (MW)
# BM Unit ID
# T_HOWBO-3                                     440.0
# T_HOWAO-1                                     406.0
# T_HOWAO-2                                     406.0
# T_HOWAO-3                                     406.0
# T_WLNYO-3                                     330.0
# ...                                             ...
# T_COUWW-1                                      21.0
# T_ANSUW-1                                      19.0
# E_TULWW-1                                      17.0
# E_CLFLW-1                                      15.0
# E_TLYMW-1                                      15.0
#
# [81 rows x 37 columns]

# %% [markdown]
# # Joining
# I think at this point it's best to dump both to Excel and do some manual joining, because it's too fuzzy to do automatically.
#
# There are only 81 wind assets in the BM apparently? This doesn't seem enough - from the BMUFuel unit sheet we have 196!
#
# Might need to fiddle with the join
